# %% [markdown]
# # 1. What is the result of the code, and why?

# %% [markdown]
# &gt;&gt;&gt; def func(a, b=6, c=8):
# print(a, b, c)
# &gt;&gt;&gt; func(1, 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <u>Explanation</u>: func(1, 2) will print 1 2 8 on the console because as per the function func definition, the value of third parameter c is by default 8 if not passed explicitly

# %% [markdown]
# # 2. What is the result of this code, and why?

# %% [markdown]
# &gt;&gt;&gt; def func(a, b, c=5):
# print(a, b, c)
# &gt;&gt;&gt; func(1, c=3, b=2)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <u>Explanation</u>: b and c are identified as named arguments whereas 1 is identified as positional arguement by func

# %% [markdown]
# # 3. How about this code: what is its result, and why?

# %% [markdown]
# &gt;&gt;&gt; def func(a, *pargs):
# print(a, pargs)
# &gt;&gt;&gt; func(1, 2, 3)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In Python, we can pass a variable number of arguments to a function using special symbols.
#
# There are two special symbols:
#
#
# 1)*args (Non Keyword Arguments)
#
# 2)**kwargs (Keyword Arguments)
#
# We use *args and ***kwargs as an argument when we are unsure about the number of arguments to pass in the functions.
#
# Python has *args which allow us to pass the variable number of non keyword arguments to function.

# %% [markdown]
# # 4. What does this code print, and why?

# %% [markdown]
# &gt;&gt;&gt; def func(a, **kargs):
# print(a, kargs)
# &gt;&gt;&gt; func(a=1, c=3, b=2)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <U>Explanation</U>: Python passes variable length non keyword argument to function using *args but we cannot use this to pass keyword argument.
#
# For this problem Python has got a solution called ***kwargs, it allows us to pass the variable length of keyword arguments to the function.
#
# The arguments are passed as a dictionary and these arguments make a dictionary inside function with name same as the parameter excluding double asterisk
#
# <u>Things to Remember</u>:
#
# *args and ***kwargs are special keyword which allows function to take variable length argument.
#
# *args passes variable number of non-keyworded arguments and on which operation of the tuple can be performed.
#
# **kwargs passes variable number of keyword arguments dictionary to function on which operation of a dictionary can be performed.
#
# *args and ***kwargs make the function flexible.

# %% [markdown]
# # 5. What gets printed by this, and explain?

# %% [markdown]
# &gt;&gt;&gt; def func(a, b, c=8, d=5): print(a, b, c, d)
# &gt;&gt;&gt; func(1, *(5, 6))
#
# ![image.png](attachment:image.png)
#
# Explanation -> func(1, (5, 6)) will print 1 5 6 5 to the console. a will take the value of 1, d will default to 5 as it is not passed. (5, 6) will be read as comma seperated values and assigned to b, c respectively

# %% [markdown]
# # 6. what is the result of this, and explain?

# %% [markdown]
# &gt;&gt;&gt; def func(a, b, c): a = 2; b[0] = &#39;x&#39;; c[&#39;a&#39;] = &#39;y&#39;
# &gt;&gt;&gt; l=1; m=[1]; n={&#39;a&#39;:0}
# &gt;&gt;&gt; func(l, m, n)
# &gt;&gt;&gt; l, m, n

# %%
def func(a,b,c):
    a=2;
    b[0]='x'
    c['a']='y'

# %%
l=1; 
m=[1]; 
n={'a':0}
func(l,m,n)
l,m,n
# Out:
# (1, ['x'], {'a': 'y'})

# %% [markdown]
# Here in the code, the list and dict are passed as argument, and those are mutable. Here the list l and parametr b point
# to the same list in the memory location where as dict n and c point to the same memory location. Any updates to this
# list will update in the memory location
#
# l = 1 , integer values, immutable, m is list, mutable, n is dict, mutable.
# output will be = 1,['x'],{'a':'y'}
